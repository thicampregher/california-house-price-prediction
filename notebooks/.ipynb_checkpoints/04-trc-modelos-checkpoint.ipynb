# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from sklearn.compose import ColumnTransformer
from sklearn.dummy import DummyRegressor
from sklearn.linear_model import ElasticNet, LinearRegression, Ridge
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import (
    OrdinalEncoder,
    OneHotEncoder,
    PolynomialFeatures,
    PowerTransformer,
    RobustScaler,
    StandardScaler,
    QuantileTransformer,
)

from joblib import dump

from src.config import DADOS_LIMPOS, MODELO_FINAL
from src.auxiliares import dataframe_coeficientes
from src.graficos import (
    plot_coeficientes,
    plot_comparar_metricas_modelos,
    plot_residuos_estimador,
)
from src.models import (
    organiza_resultados,
    treinar_e_validar_modelo_regressao,
    grid_search_cv_regressor,
)

# %%
df = pd.read_parquet(DADOS_LIMPOS)

df.head()
# Out:
#     longitude   latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0 -122.230003  37.880001                  41          880             129
# 1 -122.220001  37.860001                  21         7099            1106
# 2 -122.260002  37.840000                  42         2555             665
# 3 -122.260002  37.849998                  50         1120             283
# 4 -122.260002  37.840000                  50         2239             455
#
#    population  households  median_income  median_house_value ocean_proximity  \
# 0         322         126         8.3252              452600        NEAR BAY
# 1        2401        1138         8.3014              358500        NEAR BAY
# 2        1206         595         2.0804              226700        NEAR BAY
# 3         697         264         2.1250              140000        NEAR BAY
# 4         990         419         1.9911              158700        NEAR BAY
#
#    median_income_cat  rooms_per_household  population_per_household  \
# 0                  5             6.984127                  2.555556
# 1                  5             6.238137                  2.109842
# 2                  2             4.294117                  2.026891
# 3                  2             4.242424                  2.640152
# 4                  2             5.343676                  2.362768
#
#    bedrooms_per_room
# 0           0.146591
# 1           0.155797
# 2           0.260274
# 3           0.252679
# 4           0.203216

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17564 entries, 0 to 17563
# Data columns (total 14 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   longitude                 17564 non-null  float32
#  1   latitude                  17564 non-null  float32
#  2   housing_median_age        17564 non-null  int8
#  3   total_rooms               17564 non-null  int16
#  4   total_bedrooms            17564 non-null  int16
#  5   population                17564 non-null  int16
#  6   households                17564 non-null  int16
#  7   median_income             17564 non-null  float32
#  8   median_house_value        17564 non-null  int32
#  9   ocean_proximity           17564 non-null  object
#  10  median_income_cat         17564 non-null  int64
#  11  rooms_per_household       17564 non-null  float32
#  12  population_per_household  17564 non-null  float32
#  13  bedrooms_per_room         17564 non-null  float32
# dtypes: float32(6), int16(4), int32(1), int64(1), int8(1), object(1)
# memory usage: 909.2+ KB

# %%
coluna_target = ['median_house_value']

coluna_one_hot_encoder = ['ocean_proximity']

coluna_ordinal_encoder = ['median_income_cat']

# %%
colunas_robust_scaler = df.columns.difference(coluna_target + coluna_one_hot_encoder + coluna_ordinal_encoder)

colunas_robust_scaler
# Out:
# Index(['bedrooms_per_room', 'households', 'housing_median_age', 'latitude',
#        'longitude', 'median_income', 'population', 'population_per_household',
#        'rooms_per_household', 'total_bedrooms', 'total_rooms'],
#       dtype='object')

# %%
pipeline_robust = Pipeline(steps=[
    ('robust_scaler', RobustScaler()),
    ('poly', PolynomialFeatures(degree=1, include_bias=False)),
])

preprocessamento = ColumnTransformer(
    transformers=[
        ('ordinal_encoder', OrdinalEncoder(categories='auto'), coluna_ordinal_encoder),
        ('one_hot', OneHotEncoder(drop='first'), coluna_one_hot_encoder),
        ('robust_scaler_poly', pipeline_robust, colunas_robust_scaler)
    ]
)

# %%
X = df.drop(columns=coluna_target)
y = df[coluna_target]

# %%
param_grid = {
    'regressor__preprocessor__robust_scaler_poly__poly__degree': [1, 2, 3],
    'regressor__reg__alpha': [1E-2, 5E-2, 0.1, 0.25, 0.5, 1.0, 2.0, 5.0, 10.0, 20.0]
}

# %%
grid_search = grid_search_cv_regressor(
    regressor=Ridge(),
    preprocessor=preprocessamento,
    target_transformer=QuantileTransformer(output_distribution='normal'),
    param_grid=param_grid
)

grid_search
# Out:
# GridSearchCV(cv=KFold(n_splits=5, random_state=42, shuffle=True),
#              estimator=TransformedTargetRegressor(regressor=Pipeline(steps=[('preprocessor',
#                                                                              ColumnTransformer(transformers=[('ordinal_encoder',
#                                                                                                               OrdinalEncoder(),
#                                                                                                               ['median_income_cat']),
#                                                                                                              ('one_hot',
#                                                                                                               OneHotEncoder(drop='first'),
#                                                                                                               ['ocean_proximity']),
#                                                                                                              ('robust_scaler_poly',
#                                                                                                               Pipeline(steps=[('robust_scaler',
#                                                                                                                                Ro...
#                                                                              Ridge())]),
#                                                   transformer=QuantileTransformer(output_distribution='normal')),
#              n_jobs=-1,
#              param_grid={'regressor__preprocessor__robust_scaler_poly__poly__degree': [1,
#                                                                                        2,
#                                                                                        3],
#                          'regressor__reg__alpha': [0.01, 0.05, 0.1, 0.25, 0.5,
#                                                    1.0, 2.0, 5.0, 10.0, 20.0]},
#              refit='neg_root_mean_squared_error',
#              scoring=['r2', 'neg_mean_absolute_error',
#                       'neg_root_mean_squared_error'],
#              verbose=1)

# %%
grid_search.fit(X, y)
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# GridSearchCV(cv=KFold(n_splits=5, random_state=42, shuffle=True),
#              estimator=TransformedTargetRegressor(regressor=Pipeline(steps=[('preprocessor',
#                                                                              ColumnTransformer(transformers=[('ordinal_encoder',
#                                                                                                               OrdinalEncoder(),
#                                                                                                               ['median_income_cat']),
#                                                                                                              ('one_hot',
#                                                                                                               OneHotEncoder(drop='first'),
#                                                                                                               ['ocean_proximity']),
#                                                                                                              ('robust_scaler_poly',
#                                                                                                               Pipeline(steps=[('robust_scaler',
#                                                                                                                                Ro...
#                                                                              Ridge())]),
#                                                   transformer=QuantileTransformer(output_distribution='normal')),
#              n_jobs=-1,
#              param_grid={'regressor__preprocessor__robust_scaler_poly__poly__degree': [1,
#                                                                                        2,
#                                                                                        3],
#                          'regressor__reg__alpha': [0.01, 0.05, 0.1, 0.25, 0.5,
#                                                    1.0, 2.0, 5.0, 10.0, 20.0]},
#              refit='neg_root_mean_squared_error',
#              scoring=['r2', 'neg_mean_absolute_error',
#                       'neg_root_mean_squared_error'],
#              verbose=1)

# %%
grid_search.best_params_
# Out:
# {'regressor__preprocessor__robust_scaler_poly__poly__degree': 3,
#  'regressor__reg__alpha': 20.0}

# %%
grid_search.best_score_
# Out:
# -50460.34202978261

# %%
coefs = dataframe_coeficientes(
    coefs=grid_search.best_estimator_.regressor_['reg'].coef_,
    colunas=grid_search.best_estimator_.regressor_['preprocessor'].get_feature_names_out(),
)

coefs
# Out:
#                                                     coeficiente
# robust_scaler_poly__longitude                         -0.882309
# robust_scaler_poly__latitude                          -0.787014
# one_hot__ocean_proximity_INLAND                       -0.491805
# robust_scaler_poly__population_per_household          -0.330843
# robust_scaler_poly__latitude^2                        -0.287092
# ...                                                         ...
# robust_scaler_poly__housing_median_age longitude^2     0.190753
# robust_scaler_poly__latitude median_income popu...     0.216907
# robust_scaler_poly__housing_median_age median_i...     0.246391
# robust_scaler_poly__bedrooms_per_room                  0.316393
# robust_scaler_poly__median_income                      0.963456
#
# [367 rows x 1 columns]

# %%
coefs[coefs['coeficiente'] == 0]
# Out:
# Empty DataFrame
# Columns: [coeficiente]
# Index: []

# %%
coefs[coefs['coeficiente'].between(-0.2, 0.2) & (coefs['coeficiente'] != 0)]
# Out:
#                                                     coeficiente
# robust_scaler_poly__longitude^3                       -0.197945
# one_hot__ocean_proximity_NEAR BAY                     -0.195247
# robust_scaler_poly__longitude^2 rooms_per_house...    -0.175237
# robust_scaler_poly__housing_median_age median_i...    -0.170467
# robust_scaler_poly__latitude^2 population             -0.170113
# ...                                                         ...
# robust_scaler_poly__bedrooms_per_room housing_m...     0.170141
# robust_scaler_poly__bedrooms_per_room median_in...     0.175741
# robust_scaler_poly__latitude^2 longitude               0.184583
# robust_scaler_poly__longitude median_income pop...     0.185648
# robust_scaler_poly__housing_median_age longitude^2     0.190753
#
# [351 rows x 1 columns]

# %%
plot_coeficientes(coefs[~coefs['coeficiente'].between(-0.2, 0.2)])

# %%
regressors = {
    'DummyRegressor': {
        'preprocessor': None,
        'regressor': DummyRegressor(strategy='mean'),
        'target_transformer': None
    },

    'Ridge': {
        'preprocessor': preprocessamento,
        'regressor': LinearRegression(),
        'target_transformer': None
    },

    'Ridge_target': {
        'preprocessor': preprocessamento,
        'regressor': LinearRegression(),
        'target_transformer': QuantileTransformer(output_distribution='normal')
    },

    'Ridge_grid_search': {
        'preprocessor': grid_search.best_estimator_.regressor_['preprocessor'],
        'regressor': grid_search.best_estimator_.regressor_['reg'],
        'target_transformer': grid_search.best_estimator_.transformer_
    },
}

# %%
resultados = {
    nome_modelo: treinar_e_validar_modelo_regressao(X, y, **regressor)
    for nome_modelo, regressor in regressors.items()
}

df_resultados = organiza_resultados(resultados)

df_resultados
# Out:
#                 model  fit_time score_time   test_r2  \
# 0      DummyRegressor  0.024329   0.017407 -0.000081
# 1      DummyRegressor  0.009407   0.014806 -0.000146
# 2      DummyRegressor  0.012053   0.014273 -0.001737
# 3      DummyRegressor  0.002366   0.026561 -0.000101
# 4      DummyRegressor  0.013895   0.012797 -0.000114
# 5               Ridge   0.12893   0.034835  0.682162
# 6               Ridge  0.088968   0.039696   0.66999
# 7               Ridge  0.093881   0.035276  0.649247
# 8               Ridge  0.080533   0.031953  0.669873
# 9               Ridge  0.095776   0.026416  0.669023
# 10       Ridge_target  0.115173   0.043067  0.692302
# 11       Ridge_target  0.113922   0.038943  0.678683
# 12       Ridge_target  0.113025   0.039191  0.654443
# 13       Ridge_target  0.114058   0.030888  0.683953
# 14       Ridge_target  0.128292   0.030354  0.682977
# 15  Ridge_grid_search  0.504438   0.053996  0.744416
# 16  Ridge_grid_search  0.539406   0.061715  0.723538
# 17  Ridge_grid_search   0.50932   0.057247  0.697403
# 18  Ridge_grid_search  0.530302    0.06126  0.725301
# 19  Ridge_grid_search  0.518691   0.057335  0.725467
#
#    test_neg_mean_absolute_error test_neg_root_mean_squared_error time_seconds
# 0                 -77516.042766                    -96239.705692     0.041737
# 1                 -75787.787194                    -95217.629397     0.024212
# 2                 -76753.598961                    -96253.253947     0.026327
# 3                 -76837.804811                    -95983.885799     0.028927
# 4                 -76617.245449                    -96182.764729     0.026692
# 5                 -39855.690996                    -54254.958188     0.163765
# 6                 -40272.565467                    -54695.230283     0.128663
# 7                  -42178.05929                    -56955.988706     0.129157
# 8                 -40806.492497                    -55146.318803     0.112487
# 9                 -40788.496497                     -55331.35106     0.122192
# 10                -37800.179117                    -53382.496858     0.158241
# 11                -38268.959398                    -53970.027745     0.152865
# 12                -40281.721639                    -56532.479416     0.152216
# 13                -38599.101074                    -53957.531075     0.144946
# 14                 -38405.92913                    -54152.415674     0.158646
# 15                -34133.178023                    -48652.287518     0.558433
# 16                -35045.625106                    -50061.467867     0.601121
# 17                -37071.737106                    -52901.819821     0.566567
# 18                -35303.625027                    -50304.285147     0.591562
# 19                -35311.970305                    -50392.933205     0.576025

# %%
df_resultados.groupby('model').mean()
# Out:
#                    fit_time score_time   test_r2 test_neg_mean_absolute_error  \
# model
# DummyRegressor      0.01241   0.017169 -0.000436                -76702.495836
# Ridge              0.097618   0.033635  0.668059                 -40780.26095
# Ridge_grid_search  0.520431    0.05831  0.723225                -35373.227113
# Ridge_target       0.116894   0.036489  0.678472                -38671.178072
#
#                   test_neg_root_mean_squared_error time_seconds
# model
# DummyRegressor                       -95975.447913     0.029579
# Ridge                                -55276.769408     0.131253
# Ridge_grid_search                    -50462.558712     0.578742
# Ridge_target                         -54398.990154     0.153383

# %%
df_resultados.groupby('model').mean().sort_values(by='test_neg_root_mean_squared_error', ascending=False)
# Out:
#                    fit_time score_time   test_r2 test_neg_mean_absolute_error  \
# model
# Ridge_grid_search  0.520431    0.05831  0.723225                -35373.227113
# Ridge_target       0.116894   0.036489  0.678472                -38671.178072
# Ridge              0.097618   0.033635  0.668059                 -40780.26095
# DummyRegressor      0.01241   0.017169 -0.000436                -76702.495836
#
#                   test_neg_root_mean_squared_error time_seconds
# model
# Ridge_grid_search                    -50462.558712     0.578742
# Ridge_target                         -54398.990154     0.153383
# Ridge                                -55276.769408     0.131253
# DummyRegressor                       -95975.447913     0.029579

# %%
plot_comparar_metricas_modelos(df_resultados)

# %%
plot_residuos_estimador(grid_search.best_estimator_, X, y, eng_formatter=True)

# %% [markdown]
# https://scikit-learn.org/stable/model_persistence.html

# %%
dump(grid_search.best_estimator_, MODELO_FINAL)
# Out:
# ['C:\\Users\\trc_g\\hashtag\\014_regressao_com_modelos_lineares\\05_projeto\\modelos\\ridge_pylyfeat_target_quantile.joblib']
